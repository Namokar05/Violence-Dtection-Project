# %%
import os
import platform
from IPython.display import clear_output
print(platform.platform())

def resolve_dir(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)

def reset_path(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)
    else:
        os.system('rm -f {}/*'.format( Dir))
# Out:
# Windows-10-10.0.22621-SP0

# %%
import tensorflow as tf
tf.random.set_seed(73)
TPU_INIT = False

if TPU_INIT:
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
        tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

    except ValueError:
        raise BaseException('ERROR: Not connected to a TPU runtime!')
else:
    # !nvidia-smi
;
print("Tensorflow version " + tf.__version__)
# Out:
# Wed Oct 25 12:04:26 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.99                 Driver Version: 536.99       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 2050      WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   43C    P8               3W /  25W |    100MiB /  4096MiB |     49%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A     17032    C+G   ...Brave-Browser\Application\brave.exe    N/A      |
# +---------------------------------------------------------------------------------------+
# Tensorflow version 2.13.1

# %%
MyDrive = '/kaggle/working'
PROJECT_DIR = 'C:/Users/hares/Downloads/RWF-2000'

# %% [markdown]
# ## **Preprocessing**
# + **Getting frames form video**
# + **Some image argumentations**

# %%
import cv2        #read pic
import os         #mess with os (use system dir)
import imageio     #img to arr
import imgaug.augmenters as iaa         # imgaug cnn learn  // imgaug for img editing (brightness,....)
import imgaug as ia

IMG_SIZE = 128
ColorChannels = 3

def video_to_frames(video):
    vidcap = cv2.VideoCapture(video)

    import math
    rate = math.floor(vidcap.get(3))
    count = 0

    ImageFrames = []
    while vidcap.isOpened():
        ID = vidcap.get(1)
        success, image = vidcap.read()

        if success:
            # ....(removed frame skiping)
            if (ID % 7 == 0):
                flip = iaa.Fliplr(1.0)
                zoom = iaa.Affine(scale=1.3)
                random_brightness = iaa.Multiply((1, 1.3))
                rotate = iaa.Affine(rotate=(-25, 25))

                image_aug = flip(image = image)
                image_aug = random_brightness(image = image_aug)
                image_aug = zoom(image = image_aug)
                image_aug = rotate(image = image_aug)

                rgb_img = cv2.cvtColor(image_aug, cv2.COLOR_BGR2RGB)
                resized = cv2.resize(rgb_img, (IMG_SIZE, IMG_SIZE))
                ImageFrames.append(resized)

            count += 1
        else:
            break

    vidcap.release()

    return ImageFrames

# %%
# %%time
from tqdm import tqdm

VideoDataDir = PROJECT_DIR + '/train'
print('we have \n{} Violence videos \n{} NonViolence videos'.format(
              len(os.listdir(VideoDataDir + '/Violence')), 
              len(os.listdir(VideoDataDir + '/NonViolence'))))

X_original = []
y_original = []

print('We have used 1589 clips')
CLASSES = ["NonViolence", "Violence"]
#700 <- 350 + 350

for category in os.listdir(VideoDataDir):
    path = os.path.join(VideoDataDir, category)
    class_num = CLASSES.index(category)
    for i, video in enumerate(tqdm(os.listdir(path)[0:])):
        frames = video_to_frames(path + '/' + video)
        for j, frame in enumerate(frames):
            X_original.append(frame)
            y_original.append(class_num)
# Out:
# we have
# 789 Violence videos
# 800 NonViolence videos
# We have used 1589 clips
#   8%|██████▏                                                                         | 62/800 [00:34<06:45,  1.82it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:19
#
# Cell In[163], line 20, in video_to_frames(video)
#      18 while vidcap.isOpened():
#      19     ID = vidcap.get(1)
# ---> 20     success, image = vidcap.read()
#      22     if success:
#      23         # ....(removed frame skiping)
#      24         if (ID % 7 == 0):
#
# KeyboardInterrupt:

# %%
import numpy as np
X_original = np.array(X_original).reshape(-1 , IMG_SIZE * IMG_SIZE * 3)
y_original = np.array(y_original)
len(X_original)
# Out:
# 39725

# %%
from sklearn.model_selection import StratifiedShuffleSplit

stratified_sample = StratifiedShuffleSplit(n_splits=2, test_size=0.3, random_state=73)

for train_index, test_index in stratified_sample.split(X_original, y_original):
    X_train, X_test = X_original[train_index], X_original[test_index]
    y_train, y_test = y_original[train_index], y_original[test_index]

X_train_nn = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255
X_test_nn = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255

# %% [markdown]
# ## **Model Training**

# %%
# !pip install imutils
clear_output()

# %%
import cv2
import os
import numpy as np
import pickle
import matplotlib
matplotlib.use("Agg")

from keras.layers import Input
from keras.models import Model
from keras.layers import Dropout,Flatten,Dense
 

import matplotlib.pyplot as plt

# %%
epochs = 50

from keras import regularizers
kernel_regularizer = regularizers.l2(0.0001)

from keras.applications.mobilenet_v2 import MobileNetV2

def load_layers():
    input_tensor = Input(shape=(IMG_SIZE, IMG_SIZE, ColorChannels))
    baseModel = MobileNetV2(pooling='avg',
                            include_top=False,
                            input_tensor=input_tensor)

    headModel = baseModel.output
    headModel = Dense(1, activation="sigmoid")(headModel)
    model = Model(inputs=baseModel.input, outputs=headModel)

    for layer in baseModel.layers:
        layer.trainable = False

    print("Compiling model...")
    model.compile(loss="binary_crossentropy",
                    optimizer='adam',
                    metrics=["accuracy"])

    return model

if TPU_INIT:
    with tpu_strategy.scope():
        model = load_layers()
else:
    model = load_layers()

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Compiling model...
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 64, 64, 32)           864       ['input_4[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 64, 64, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 64, 64, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 64, 64, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 64, 64, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 64, 64, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 64, 64, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 64, 64, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 64, 64, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 64, 64, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 64, 64, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 65, 65, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 32, 32, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 32, 32, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 32, 32, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 32, 32, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 32, 32, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 32, 32, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 32, 32, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 32, 32, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 32, 32, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 33, 33, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 16, 16, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 16, 16, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 16, 16, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 16, 16, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 16, 16, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 16, 16, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 17, 17, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 8, 8, 192)            1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 8, 8, 192)            768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 8, 8, 192)            0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 8, 8, 64)             12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 8, 8, 64)             0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 8, 8, 64)             0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 8, 8, 64)             0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 8, 8, 384)            24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 8, 8, 384)            1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 8, 8, 384)            0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 8, 8, 384)            3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 8, 8, 384)            1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 8, 8, 384)            0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 8, 8, 96)             36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 8, 8, 96)             384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 8, 8, 96)             384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 8, 8, 96)             0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 8, 8, 96)             384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 8, 8, 96)             0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 9, 9, 576)            0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 4, 4, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 4, 4, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 4, 4, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 4, 4, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 4, 4, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 4, 4, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 4, 4, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 4, 4, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 4, 4, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 4, 4, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 4, 4, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 4, 4, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 4, 4, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 4, 4, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d_3  (None, 1280)                 0         ['out_relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 1)                    1281      ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 2259265 (8.62 MB)
# Trainable params: 1281 (5.00 KB)
# Non-trainable params: 2257984 (8.61 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau

patience = 3

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005

batch_size = 4

if TPU_INIT:
    max_lr = max_lr * tpu_strategy.num_replicas_in_sync
    batch_size = batch_size * tpu_strategy.num_replicas_in_sync

rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8

def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr


class myCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if ((logs.get('accuracy')>=0.999)):
            print("\nLimits Reached cancelling training!")
            self.model.stop_training = True

# %%
end_callback = myCallback()

lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

early_stopping = EarlyStopping(patience = patience, monitor='val_loss',
                                 mode='min', restore_best_weights=True,
                                 verbose = 1, min_delta = .00075)

PROJECT_DIR = MyDrive + '/RiskDetection'

lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')

os.system('rm -rf ./logs/')

import datetime
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

checkpoint_filepath = 'ModelWeights.h5'

model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor='val_loss',
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)


callbacks = [end_callback, lr_callback, model_checkpoints, tensorboard_callback, early_stopping, lr_plat]

if TPU_INIT:
    callbacks = [end_callback, lr_callback, model_checkpoints, early_stopping, lr_plat]

# %%
print('Training head...')
#model.load_weights('./Model_Weights.h5')

history = model.fit(X_train_nn ,y_train, epochs=epochs,
                        callbacks=callbacks,
                        validation_data = (X_test_nn, y_test),
                        batch_size=batch_size)

print('\nRestoring best Weights for MobileNetV2')
model.load_weights(checkpoint_filepath)
# Out:
# Training head...
# Epoch 1/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.7009 - accuracy: 0.6155
# Epoch 1: val_loss improved from inf to 0.66233, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 571s 82ms/step - loss: 0.7009 - accuracy: 0.6155 - val_loss: 0.6623 - val_accuracy: 0.6442 - lr: 1.0000e-05
# Epoch 2/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.6243 - accuracy: 0.6653
# Epoch 2: val_loss improved from 0.66233 to 0.60465, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 576s 83ms/step - loss: 0.6243 - accuracy: 0.6653 - val_loss: 0.6046 - val_accuracy: 0.6863 - lr: 1.8000e-05
# Epoch 3/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.5792 - accuracy: 0.6949
# Epoch 3: val_loss improved from 0.60465 to 0.56835, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 552s 79ms/step - loss: 0.5792 - accuracy: 0.6949 - val_loss: 0.5683 - val_accuracy: 0.7077 - lr: 2.6000e-05
# Epoch 4/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.5472 - accuracy: 0.7164
# Epoch 4: val_loss improved from 0.56835 to 0.54195, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 576s 83ms/step - loss: 0.5471 - accuracy: 0.7164 - val_loss: 0.5419 - val_accuracy: 0.7218 - lr: 3.4000e-05
# Epoch 5/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.5218 - accuracy: 0.7359
# Epoch 5: val_loss improved from 0.54195 to 0.52579, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 578s 83ms/step - loss: 0.5218 - accuracy: 0.7359 - val_loss: 0.5258 - val_accuracy: 0.7405 - lr: 4.2000e-05
# Epoch 6/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.5015 - accuracy: 0.7509
# Epoch 6: val_loss improved from 0.52579 to 0.50718, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 516s 74ms/step - loss: 0.5015 - accuracy: 0.7509 - val_loss: 0.5072 - val_accuracy: 0.7464 - lr: 5.0000e-05
# Epoch 7/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4858 - accuracy: 0.7611
# Epoch 7: val_loss improved from 0.50718 to 0.49277, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 500s 72ms/step - loss: 0.4858 - accuracy: 0.7611 - val_loss: 0.4928 - val_accuracy: 0.7585 - lr: 4.2000e-05
# Epoch 8/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4754 - accuracy: 0.7682
# Epoch 8: val_loss improved from 0.49277 to 0.48617, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 387s 56ms/step - loss: 0.4754 - accuracy: 0.7682 - val_loss: 0.4862 - val_accuracy: 0.7650 - lr: 3.5600e-05
# Epoch 9/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4678 - accuracy: 0.7735
# Epoch 9: val_loss improved from 0.48617 to 0.48054, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 385s 55ms/step - loss: 0.4678 - accuracy: 0.7735 - val_loss: 0.4805 - val_accuracy: 0.7673 - lr: 3.0480e-05
# Epoch 10/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4623 - accuracy: 0.7781
# Epoch 10: val_loss improved from 0.48054 to 0.47686, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 369s 53ms/step - loss: 0.4623 - accuracy: 0.7780 - val_loss: 0.4769 - val_accuracy: 0.7711 - lr: 2.6384e-05
# Epoch 11/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4579 - accuracy: 0.7813
# Epoch 11: val_loss improved from 0.47686 to 0.47303, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 380s 55ms/step - loss: 0.4579 - accuracy: 0.7813 - val_loss: 0.4730 - val_accuracy: 0.7719 - lr: 2.3107e-05
# Epoch 12/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4544 - accuracy: 0.7838
# Epoch 12: val_loss improved from 0.47303 to 0.47003, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 362s 52ms/step - loss: 0.4544 - accuracy: 0.7839 - val_loss: 0.4700 - val_accuracy: 0.7737 - lr: 2.0486e-05
# Epoch 13/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4514 - accuracy: 0.7866
# Epoch 13: val_loss improved from 0.47003 to 0.46800, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 445s 64ms/step - loss: 0.4514 - accuracy: 0.7866 - val_loss: 0.4680 - val_accuracy: 0.7751 - lr: 1.8389e-05
# Epoch 14/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4489 - accuracy: 0.7871
# Epoch 14: val_loss improved from 0.46800 to 0.46665, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 466s 67ms/step - loss: 0.4489 - accuracy: 0.7871 - val_loss: 0.4667 - val_accuracy: 0.7740 - lr: 1.6711e-05
# Epoch 15/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4467 - accuracy: 0.7893
# Epoch 15: val_loss improved from 0.46665 to 0.46466, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 465s 67ms/step - loss: 0.4467 - accuracy: 0.7893 - val_loss: 0.4647 - val_accuracy: 0.7771 - lr: 1.5369e-05
# Epoch 16/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4449 - accuracy: 0.7902
# Epoch 16: val_loss improved from 0.46466 to 0.46317, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 491s 71ms/step - loss: 0.4449 - accuracy: 0.7902 - val_loss: 0.4632 - val_accuracy: 0.7772 - lr: 1.4295e-05
# Epoch 17/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4431 - accuracy: 0.7910
# Epoch 17: val_loss improved from 0.46317 to 0.46192, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 475s 68ms/step - loss: 0.4431 - accuracy: 0.7910 - val_loss: 0.4619 - val_accuracy: 0.7796 - lr: 1.3436e-05
# Epoch 18/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4415 - accuracy: 0.7913
# Epoch 18: val_loss improved from 0.46192 to 0.46178, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 461s 66ms/step - loss: 0.4415 - accuracy: 0.7913 - val_loss: 0.4618 - val_accuracy: 0.7775 - lr: 1.2749e-05
# Epoch 19/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4404 - accuracy: 0.7931
# Epoch 19: val_loss improved from 0.46178 to 0.45960, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 468s 67ms/step - loss: 0.4404 - accuracy: 0.7931 - val_loss: 0.4596 - val_accuracy: 0.7791 - lr: 1.2199e-05
# Epoch 20/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.7933
# Epoch 20: val_loss improved from 0.45960 to 0.45899, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 472s 68ms/step - loss: 0.4390 - accuracy: 0.7933 - val_loss: 0.4590 - val_accuracy: 0.7799 - lr: 1.1759e-05
# Epoch 21/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4380 - accuracy: 0.7947
# Epoch 21: val_loss improved from 0.45899 to 0.45778, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 481s 69ms/step - loss: 0.4380 - accuracy: 0.7947 - val_loss: 0.4578 - val_accuracy: 0.7813 - lr: 1.1407e-05
# Epoch 22/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4368 - accuracy: 0.7952
# Epoch 22: val_loss improved from 0.45778 to 0.45725, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 478s 69ms/step - loss: 0.4368 - accuracy: 0.7952 - val_loss: 0.4572 - val_accuracy: 0.7819 - lr: 1.1126e-05
# Epoch 23/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4358 - accuracy: 0.7959
# Epoch 23: val_loss improved from 0.45725 to 0.45640, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 485s 70ms/step - loss: 0.4358 - accuracy: 0.7959 - val_loss: 0.4564 - val_accuracy: 0.7823 - lr: 1.0901e-05
# Epoch 24/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4348 - accuracy: 0.7969
# Epoch 24: val_loss improved from 0.45640 to 0.45550, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 493s 71ms/step - loss: 0.4348 - accuracy: 0.7969 - val_loss: 0.4555 - val_accuracy: 0.7828 - lr: 1.0721e-05
# Epoch 25/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4337 - accuracy: 0.7975
# Epoch 25: val_loss improved from 0.45550 to 0.45468, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 493s 71ms/step - loss: 0.4338 - accuracy: 0.7974 - val_loss: 0.4547 - val_accuracy: 0.7829 - lr: 1.0576e-05
# Epoch 26/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4329 - accuracy: 0.7980
# Epoch 26: val_loss improved from 0.45468 to 0.45396, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 493s 71ms/step - loss: 0.4329 - accuracy: 0.7980 - val_loss: 0.4540 - val_accuracy: 0.7832 - lr: 1.0461e-05
# Epoch 27/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4319 - accuracy: 0.7987
# Epoch 27: val_loss improved from 0.45396 to 0.45373, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 493s 71ms/step - loss: 0.4320 - accuracy: 0.7986 - val_loss: 0.4537 - val_accuracy: 0.7842 - lr: 1.0369e-05
# Epoch 28/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4312 - accuracy: 0.7996
# Epoch 28: val_loss improved from 0.45373 to 0.45273, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 498s 72ms/step - loss: 0.4313 - accuracy: 0.7996 - val_loss: 0.4527 - val_accuracy: 0.7850 - lr: 1.0295e-05
# Epoch 29/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4305 - accuracy: 0.8004
# Epoch 29: val_loss improved from 0.45273 to 0.45198, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 485s 70ms/step - loss: 0.4305 - accuracy: 0.8004 - val_loss: 0.4520 - val_accuracy: 0.7850 - lr: 1.0236e-05
# Epoch 30/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4297 - accuracy: 0.7999
# Epoch 30: val_loss improved from 0.45198 to 0.45173, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 490s 70ms/step - loss: 0.4297 - accuracy: 0.7999 - val_loss: 0.4517 - val_accuracy: 0.7860 - lr: 1.0189e-05
# Epoch 31/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4288 - accuracy: 0.8006
# Epoch 31: val_loss improved from 0.45173 to 0.45076, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 490s 70ms/step - loss: 0.4288 - accuracy: 0.8006 - val_loss: 0.4508 - val_accuracy: 0.7856 - lr: 1.0151e-05
# Epoch 32/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4281 - accuracy: 0.8012
# Epoch 32: val_loss did not improve from 0.45076
# 6952/6952 [==============================] - 494s 71ms/step - loss: 0.4281 - accuracy: 0.8012 - val_loss: 0.4508 - val_accuracy: 0.7870 - lr: 1.0121e-05
# Epoch 33/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4274 - accuracy: 0.8015
# Epoch 33: val_loss improved from 0.45076 to 0.45012, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 489s 70ms/step - loss: 0.4274 - accuracy: 0.8015 - val_loss: 0.4501 - val_accuracy: 0.7879 - lr: 1.0097e-05
# Epoch 34/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4267 - accuracy: 0.8025
# Epoch 34: val_loss improved from 0.45012 to 0.44926, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 494s 71ms/step - loss: 0.4267 - accuracy: 0.8025 - val_loss: 0.4493 - val_accuracy: 0.7877 - lr: 1.0077e-05
# Epoch 35/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4260 - accuracy: 0.8033
# Epoch 35: val_loss improved from 0.44926 to 0.44880, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 503s 72ms/step - loss: 0.4260 - accuracy: 0.8034 - val_loss: 0.4488 - val_accuracy: 0.7877 - lr: 1.0062e-05
# Epoch 36/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4253 - accuracy: 0.8030
# Epoch 36: val_loss improved from 0.44880 to 0.44813, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 508s 73ms/step - loss: 0.4253 - accuracy: 0.8030 - val_loss: 0.4481 - val_accuracy: 0.7887 - lr: 1.0050e-05
# Epoch 37/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4248 - accuracy: 0.8028
# Epoch 37: val_loss improved from 0.44813 to 0.44782, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 489s 70ms/step - loss: 0.4248 - accuracy: 0.8028 - val_loss: 0.4478 - val_accuracy: 0.7892 - lr: 1.0040e-05
# Epoch 38/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4241 - accuracy: 0.8038
# Epoch 38: val_loss improved from 0.44782 to 0.44740, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 502s 72ms/step - loss: 0.4241 - accuracy: 0.8038 - val_loss: 0.4474 - val_accuracy: 0.7896 - lr: 1.0032e-05
# Epoch 39/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4236 - accuracy: 0.8045
# Epoch 39: val_loss improved from 0.44740 to 0.44667, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 505s 73ms/step - loss: 0.4236 - accuracy: 0.8045 - val_loss: 0.4467 - val_accuracy: 0.7906 - lr: 1.0025e-05
# Epoch 40/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4228 - accuracy: 0.8040
# Epoch 40: val_loss improved from 0.44667 to 0.44629, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 505s 73ms/step - loss: 0.4228 - accuracy: 0.8040 - val_loss: 0.4463 - val_accuracy: 0.7905 - lr: 1.0020e-05
# Epoch 41/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4223 - accuracy: 0.8043
# Epoch 41: val_loss improved from 0.44629 to 0.44583, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 478s 69ms/step - loss: 0.4223 - accuracy: 0.8043 - val_loss: 0.4458 - val_accuracy: 0.7912 - lr: 1.0016e-05
# Epoch 42/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4216 - accuracy: 0.8046
# Epoch 42: val_loss improved from 0.44583 to 0.44544, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 504s 73ms/step - loss: 0.4216 - accuracy: 0.8046 - val_loss: 0.4454 - val_accuracy: 0.7918 - lr: 1.0013e-05
# Epoch 43/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4212 - accuracy: 0.8050
# Epoch 43: val_loss improved from 0.44544 to 0.44494, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 511s 74ms/step - loss: 0.4212 - accuracy: 0.8050 - val_loss: 0.4449 - val_accuracy: 0.7924 - lr: 1.0010e-05
# Epoch 44/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4206 - accuracy: 0.8055
# Epoch 44: val_loss improved from 0.44494 to 0.44457, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 485s 70ms/step - loss: 0.4206 - accuracy: 0.8055 - val_loss: 0.4446 - val_accuracy: 0.7923 - lr: 1.0008e-05
# Epoch 45/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4200 - accuracy: 0.8057
# Epoch 45: val_loss improved from 0.44457 to 0.44416, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 491s 71ms/step - loss: 0.4200 - accuracy: 0.8057 - val_loss: 0.4442 - val_accuracy: 0.7921 - lr: 1.0007e-05
# Epoch 46/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4195 - accuracy: 0.8069
# Epoch 46: val_loss improved from 0.44416 to 0.44374, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 477s 69ms/step - loss: 0.4195 - accuracy: 0.8069 - val_loss: 0.4437 - val_accuracy: 0.7934 - lr: 1.0005e-05
# Epoch 47/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4190 - accuracy: 0.8069
# Epoch 47: val_loss improved from 0.44374 to 0.44340, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 495s 71ms/step - loss: 0.4190 - accuracy: 0.8069 - val_loss: 0.4434 - val_accuracy: 0.7934 - lr: 1.0004e-05
# Epoch 48/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4184 - accuracy: 0.8071
# Epoch 48: val_loss improved from 0.44340 to 0.44318, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 490s 71ms/step - loss: 0.4184 - accuracy: 0.8071 - val_loss: 0.4432 - val_accuracy: 0.7930 - lr: 1.0003e-05
# Epoch 49/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4180 - accuracy: 0.8075
# Epoch 49: val_loss improved from 0.44318 to 0.44262, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 495s 71ms/step - loss: 0.4180 - accuracy: 0.8075 - val_loss: 0.4426 - val_accuracy: 0.7935 - lr: 1.0003e-05
# Epoch 50/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4175 - accuracy: 0.8083
# Epoch 50: val_loss improved from 0.44262 to 0.44245, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 485s 70ms/step - loss: 0.4175 - accuracy: 0.8083 - val_loss: 0.4425 - val_accuracy: 0.7931 - lr: 1.0002e-05
# Epoch 51/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4169 - accuracy: 0.8080
# Epoch 51: val_loss improved from 0.44245 to 0.44224, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 487s 70ms/step - loss: 0.4169 - accuracy: 0.8080 - val_loss: 0.4422 - val_accuracy: 0.7940 - lr: 1.0002e-05
# Epoch 52/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4164 - accuracy: 0.8093
# Epoch 52: val_loss improved from 0.44224 to 0.44175, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 486s 70ms/step - loss: 0.4164 - accuracy: 0.8093 - val_loss: 0.4418 - val_accuracy: 0.7944 - lr: 1.0001e-05
# Epoch 53/55
# 6952/6952 [==============================] - ETA: 0s - loss: 0.4159 - accuracy: 0.8099
# Epoch 53: val_loss improved from 0.44175 to 0.44172, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 488s 70ms/step - loss: 0.4159 - accuracy: 0.8099 - val_loss: 0.4417 - val_accuracy: 0.7935 - lr: 1.0001e-05
# Epoch 54/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4156 - accuracy: 0.8082
# Epoch 54: val_loss improved from 0.44172 to 0.44104, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 480s 69ms/step - loss: 0.4156 - accuracy: 0.8082 - val_loss: 0.4410 - val_accuracy: 0.7949 - lr: 1.0001e-05
# Epoch 55/55
# 6951/6952 [============================>.] - ETA: 0s - loss: 0.4152 - accuracy: 0.8092
# Epoch 55: val_loss improved from 0.44104 to 0.44086, saving model to ModelWeights.h5
# 6952/6952 [==============================] - 487s 70ms/step - loss: 0.4152 - accuracy: 0.8092 - val_loss: 0.4409 - val_accuracy: 0.7949 - lr: 1.0001e-05
#
# Restoring best Weights for MobileNetV2

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure()
    train_values = history.history[item][0:index]
    plt.plot(train_values)
    test_values = history.history['val_' + item][0:index]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)


def get_best_epoch(test_loss, history):
    for key, item in enumerate(history.history.items()):
        (name, arr) = item
        if name == 'val_loss':
            for i in range(len(arr)):
                if round(test_loss, 2) == round(arr[i], 2):
                    return i

def model_summary(model, history):
    print('---'*30)
    test_loss, test_accuracy = model.evaluate(X_test_nn, y_test, verbose=0)

    if history:
        index = get_best_epoch(test_loss, history)
        print('Best Epochs: ', index)

        train_accuracy = history.history['accuracy'][index]
        train_loss = history.history['loss'][index]

        print('Accuracy on train:',train_accuracy,'\tLoss on train:',train_loss)
        print('Accuracy on test:',test_accuracy,'\tLoss on test:',test_loss)
        print_graph('loss', index, history)
        print_graph('accuracy', index, history)
        print('---'*30)

# %%
model_summary(model, history)
# Out:
# ------------------------------------------------------------------------------------------
# Best Epochs:  42
# Accuracy on train: 0.8050490617752075 	Loss on train: 0.4211543798446655
# Accuracy on test: 0.7949320077896118 	Loss on test: 0.44086262583732605
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## **Evaluation on test set**

# %%
# evaluate the network
print("Evaluating network...")
predictions = model.predict(X_test_nn)
preds = predictions > 0.5
# Out:
# Evaluating network...
# 373/373 [==============================] - 66s 178ms/step

# %%
import seaborn as sns
import sklearn 
#from sklearn.metrics import roc_curve, roc_auc_score, plot_roc_curve, accuracy_score, classification_report, confusion_matrix
corr_pred = metrics.confusion_matrix(y_test, preds)

n_correct = int((corr_pred[0][0] + corr_pred[1][1]))
print('> Correct Predictions:', n_correct)
n_wrongs = int((corr_pred[0][1] + (corr_pred[1][0])))
print('> Wrong Predictions:', n_wrongs)

sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Blues")
plt.show()

print(metrics.classification_report(y_test, preds,
                           target_names=["NonViolence", "Violence"]))
# Out:
# > Correct Predictions: 9474
# > Wrong Predictions: 2444
#               precision    recall  f1-score   support
#
#  NonViolence       0.80      0.79      0.79      6000
#     Violence       0.79      0.80      0.80      5918
#
#     accuracy                           0.79     11918
#    macro avg       0.79      0.79      0.79     11918
# weighted avg       0.80      0.79      0.79     11918

# %%
args_model = "modelnew13.h5"
model.save(args_model)
# Out:
# C:\Users\hares\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
