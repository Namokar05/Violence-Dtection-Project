# %%
import os
import platform
from IPython.display import clear_output
print(platform.platform())

def resolve_dir(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)

def reset_path(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)
    else:
        os.system('rm -f {}/*'.format( Dir))
# Out:
# Windows-10-10.0.22621-SP0

# %%
import tensorflow as tf
tf.random.set_seed(73)
TPU_INIT = False

if TPU_INIT:
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
        tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

    except ValueError:
        raise BaseException('ERROR: Not connected to a TPU runtime!')
else:
    # !nvidia-smi
;
print("Tensorflow version " + tf.__version__)
# Out:
# Wed Oct 25 19:46:23 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.99                 Driver Version: 536.99       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 2050      WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   47C    P5               4W /  28W |     81MiB /  4096MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A     27684    C+G   ...Brave-Browser\Application\brave.exe    N/A      |
# +---------------------------------------------------------------------------------------+
# Tensorflow version 2.13.1

# %%
MyDrive = '/kaggle/working'
PROJECT_DIR = 'C:/Users/hares/Downloads/RWF-2000'

# %% [markdown]
# ## **Preprocessing**
# + **Getting frames form video**
# + **Some image argumentations**

# %%
import cv2        #read pic
import os         #mess with os (use system dir)
import imageio     #img to arr
import imgaug.augmenters as iaa         # imgaug cnn learn  // imgaug for img editing (brightness,....)
import imgaug as ia

IMG_SIZE = 128
ColorChannels = 3

def video_to_frames(video):
    vidcap = cv2.VideoCapture(video)

    import math
    rate = math.floor(vidcap.get(3))
    count = 0

    ImageFrames = []
    while vidcap.isOpened():
        ID = vidcap.get(1)
        success, image = vidcap.read()

        if success:
            # ....(removed frame skiping)
            if (ID % 4 == 0):
                flip = iaa.Fliplr(1.0)
                zoom = iaa.Affine(scale=1.3)
                random_brightness = iaa.Multiply((1, 1.3))
                rotate = iaa.Affine(rotate=(-25, 25))

                image_aug = flip(image = image)
                image_aug = random_brightness(image = image_aug)
                image_aug = zoom(image = image_aug)
                image_aug = rotate(image = image_aug)

                rgb_img = cv2.cvtColor(image_aug, cv2.COLOR_BGR2RGB)
                resized = cv2.resize(rgb_img, (IMG_SIZE, IMG_SIZE))
                ImageFrames.append(resized)

            count += 1
        else:
            break

    vidcap.release()

    return ImageFrames

# %%
# %%time
from tqdm import tqdm

VideoDataDir = PROJECT_DIR + '/train'
print('we have \n{} Violence videos \n{} NonViolence videos'.format(
              len(os.listdir(VideoDataDir + '/Violence')), 
              len(os.listdir(VideoDataDir + '/NonViolence'))))

X_original = []
y_original = []

print('We have used 1589 clips')
CLASSES = ["NonViolence", "Violence"]
#700 <- 350 + 350

for category in os.listdir(VideoDataDir):
    path = os.path.join(VideoDataDir, category)
    class_num = CLASSES.index(category)
    for i, video in enumerate(tqdm(os.listdir(path)[0:])):
        frames = video_to_frames(path + '/' + video)
        for j, frame in enumerate(frames):
            X_original.append(frame)
            y_original.append(class_num)
# Out:
# we have
# 789 Violence videos
# 800 NonViolence videos
# We have used 1589 clips
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [07:05<00:00,  1.88it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 789/789 [12:00<00:00,  1.10it/s]
# CPU times: total: 10min 21s
# Wall time: 19min 6s

# %%
import numpy as np
X_original = np.array(X_original).reshape(-1 , IMG_SIZE * IMG_SIZE * 3)
y_original = np.array(y_original)
len(X_original)
# Out:
# 60382

# %%
from sklearn.model_selection import StratifiedShuffleSplit

stratified_sample = StratifiedShuffleSplit(n_splits=2, test_size=0.3, random_state=73)

for train_index, test_index in stratified_sample.split(X_original, y_original):
    X_train, X_test = X_original[train_index], X_original[test_index]
    y_train, y_test = y_original[train_index], y_original[test_index]

X_train_nn = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255
X_test_nn = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255

# %% [markdown]
# ## **Model Training**

# %%
# !pip install imutils
clear_output()

# %%
import cv2
import os
import numpy as np
import pickle
import matplotlib
matplotlib.use("Agg")

from keras.layers import Input
from keras.models import Model
from keras.layers import Dropout,Flatten,Dense
 

import matplotlib.pyplot as plt

# %%
epochs = 50

from keras import regularizers
kernel_regularizer = regularizers.l2(0.0001)

from keras.applications.mobilenet_v2 import MobileNetV2

def load_layers():
    input_tensor = Input(shape=(IMG_SIZE, IMG_SIZE, ColorChannels))
    baseModel = MobileNetV2(pooling='avg',
                            include_top=False,
                            input_tensor=input_tensor)

    headModel = baseModel.output
    headModel = Dense(1, activation="sigmoid")(headModel)
    model = Model(inputs=baseModel.input, outputs=headModel)

    for layer in baseModel.layers:
        layer.trainable = False

    print("Compiling model...")
    model.compile(loss="binary_crossentropy",
                    optimizer='adam',
                    metrics=["accuracy"])

    return model

if TPU_INIT:
    with tpu_strategy.scope():
        model = load_layers()
else:
    model = load_layers()

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Compiling model...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 64, 64, 32)           864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 64, 64, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 64, 64, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 64, 64, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 64, 64, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 64, 64, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 64, 64, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 64, 64, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 64, 64, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 64, 64, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 64, 64, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 65, 65, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 32, 32, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 32, 32, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 32, 32, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 32, 32, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 32, 32, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 32, 32, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 32, 32, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 32, 32, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 32, 32, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 33, 33, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 16, 16, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 16, 16, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 16, 16, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 16, 16, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 16, 16, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 16, 16, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 17, 17, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 8, 8, 192)            1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 8, 8, 192)            768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 8, 8, 192)            0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 8, 8, 64)             12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 8, 8, 64)             0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 8, 8, 64)             0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 8, 8, 64)             0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 8, 8, 384)            24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 8, 8, 384)            1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 8, 8, 384)            0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 8, 8, 384)            3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 8, 8, 384)            1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 8, 8, 384)            0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 8, 8, 96)             36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 8, 8, 96)             384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 8, 8, 96)             384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 8, 8, 96)             0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 8, 8, 96)             384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 8, 8, 96)             0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 9, 9, 576)            0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 4, 4, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 4, 4, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 4, 4, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 4, 4, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 4, 4, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 4, 4, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 4, 4, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 4, 4, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 4, 4, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 4, 4, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 4, 4, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 4, 4, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 4, 4, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 4, 4, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                    1281      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 2259265 (8.62 MB)
# Trainable params: 1281 (5.00 KB)
# Non-trainable params: 2257984 (8.61 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau

patience = 5

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005

batch_size = 4

if TPU_INIT:
    max_lr = max_lr * tpu_strategy.num_replicas_in_sync
    batch_size = batch_size * tpu_strategy.num_replicas_in_sync

rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8

def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr


class myCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if ((logs.get('accuracy')>=0.999)):
            print("\nLimits Reached cancelling training!")
            self.model.stop_training = True

# %%
end_callback = myCallback()

lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

early_stopping = EarlyStopping(patience = patience, monitor='val_loss',
                                 mode='min', restore_best_weights=True,
                                 verbose = 1, min_delta = .00075)

PROJECT_DIR = MyDrive + '/RiskDetection'

lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')

os.system('rm -rf ./logs/')

import datetime
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

checkpoint_filepath = 'ModelWeights.h5'

model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor='val_loss',
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)


callbacks = [end_callback, lr_callback, model_checkpoints, tensorboard_callback, early_stopping, lr_plat]

if TPU_INIT:
    callbacks = [end_callback, lr_callback, model_checkpoints, early_stopping, lr_plat]

# %%
print('Training head...')
#model.load_weights('./Model_Weights.h5')

history = model.fit(X_train_nn ,y_train, epochs=epochs,
                        callbacks=callbacks,
                        validation_data = (X_test_nn, y_test),
                        batch_size=batch_size)

print('\nRestoring best Weights for MobileNetV2')
model.load_weights(checkpoint_filepath)
# Out:
# Training head...
# Epoch 1/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.7460 - accuracy: 0.5748
# Epoch 1: val_loss improved from inf to 0.67114, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 715s 67ms/step - loss: 0.7460 - accuracy: 0.5748 - val_loss: 0.6711 - val_accuracy: 0.6282 - lr: 1.0000e-05
# Epoch 2/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.6188 - accuracy: 0.6656
# Epoch 2: val_loss improved from 0.67114 to 0.59269, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 734s 69ms/step - loss: 0.6188 - accuracy: 0.6656 - val_loss: 0.5927 - val_accuracy: 0.6833 - lr: 1.8000e-05
# Epoch 3/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.5617 - accuracy: 0.7050
# Epoch 3: val_loss improved from 0.59269 to 0.54860, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 690s 65ms/step - loss: 0.5617 - accuracy: 0.7050 - val_loss: 0.5486 - val_accuracy: 0.7124 - lr: 2.6000e-05
# Epoch 4/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.5251 - accuracy: 0.7309
# Epoch 4: val_loss improved from 0.54860 to 0.51838, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 717s 68ms/step - loss: 0.5251 - accuracy: 0.7309 - val_loss: 0.5184 - val_accuracy: 0.7354 - lr: 3.4000e-05
# Epoch 5/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4984 - accuracy: 0.7500
# Epoch 5: val_loss improved from 0.51838 to 0.49792, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 705s 67ms/step - loss: 0.4983 - accuracy: 0.7500 - val_loss: 0.4979 - val_accuracy: 0.7529 - lr: 4.2000e-05
# Epoch 6/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4791 - accuracy: 0.7647
# Epoch 6: val_loss improved from 0.49792 to 0.48129, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 696s 66ms/step - loss: 0.4791 - accuracy: 0.7647 - val_loss: 0.4813 - val_accuracy: 0.7650 - lr: 5.0000e-05
# Epoch 7/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4642 - accuracy: 0.7752
# Epoch 7: val_loss improved from 0.48129 to 0.47172, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 710s 67ms/step - loss: 0.4642 - accuracy: 0.7751 - val_loss: 0.4717 - val_accuracy: 0.7698 - lr: 4.2000e-05
# Epoch 8/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4545 - accuracy: 0.7821
# Epoch 8: val_loss improved from 0.47172 to 0.46528, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 710s 67ms/step - loss: 0.4545 - accuracy: 0.7821 - val_loss: 0.4653 - val_accuracy: 0.7723 - lr: 3.5600e-05
# Epoch 9/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4480 - accuracy: 0.7865
# Epoch 9: val_loss improved from 0.46528 to 0.45989, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 718s 68ms/step - loss: 0.4480 - accuracy: 0.7865 - val_loss: 0.4599 - val_accuracy: 0.7763 - lr: 3.0480e-05
# Epoch 10/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4430 - accuracy: 0.7900
# Epoch 10: val_loss improved from 0.45989 to 0.45650, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 703s 67ms/step - loss: 0.4430 - accuracy: 0.7900 - val_loss: 0.4565 - val_accuracy: 0.7794 - lr: 2.6384e-05
# Epoch 11/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.7940
# Epoch 11: val_loss improved from 0.45650 to 0.45489, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 725s 69ms/step - loss: 0.4390 - accuracy: 0.7940 - val_loss: 0.4549 - val_accuracy: 0.7810 - lr: 2.3107e-05
# Epoch 12/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4359 - accuracy: 0.7945
# Epoch 12: val_loss improved from 0.45489 to 0.45150, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 723s 68ms/step - loss: 0.4359 - accuracy: 0.7945 - val_loss: 0.4515 - val_accuracy: 0.7824 - lr: 2.0486e-05
# Epoch 13/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.7975
# Epoch 13: val_loss improved from 0.45150 to 0.44970, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 709s 67ms/step - loss: 0.4334 - accuracy: 0.7975 - val_loss: 0.4497 - val_accuracy: 0.7841 - lr: 1.8389e-05
# Epoch 14/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4312 - accuracy: 0.7991
# Epoch 14: val_loss improved from 0.44970 to 0.44879, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 722s 68ms/step - loss: 0.4312 - accuracy: 0.7991 - val_loss: 0.4488 - val_accuracy: 0.7859 - lr: 1.6711e-05
# Epoch 15/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4294 - accuracy: 0.7993
# Epoch 15: val_loss improved from 0.44879 to 0.44716, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 746s 71ms/step - loss: 0.4294 - accuracy: 0.7993 - val_loss: 0.4472 - val_accuracy: 0.7858 - lr: 1.5369e-05
# Epoch 16/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4279 - accuracy: 0.8001
# Epoch 16: val_loss improved from 0.44716 to 0.44568, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 735s 70ms/step - loss: 0.4279 - accuracy: 0.8001 - val_loss: 0.4457 - val_accuracy: 0.7874 - lr: 1.4295e-05
# Epoch 17/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4266 - accuracy: 0.8006
# Epoch 17: val_loss improved from 0.44568 to 0.44559, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 721s 68ms/step - loss: 0.4266 - accuracy: 0.8006 - val_loss: 0.4456 - val_accuracy: 0.7869 - lr: 1.3436e-05
# Epoch 18/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4252 - accuracy: 0.8018
# Epoch 18: val_loss improved from 0.44559 to 0.44392, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 721s 68ms/step - loss: 0.4252 - accuracy: 0.8018 - val_loss: 0.4439 - val_accuracy: 0.7884 - lr: 1.2749e-05
# Epoch 19/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4241 - accuracy: 0.8025
# Epoch 19: val_loss improved from 0.44392 to 0.44323, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 730s 69ms/step - loss: 0.4241 - accuracy: 0.8025 - val_loss: 0.4432 - val_accuracy: 0.7897 - lr: 1.2199e-05
# Epoch 20/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4230 - accuracy: 0.8027
# Epoch 20: val_loss improved from 0.44323 to 0.44241, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 700s 66ms/step - loss: 0.4230 - accuracy: 0.8027 - val_loss: 0.4424 - val_accuracy: 0.7902 - lr: 1.1759e-05
# Epoch 21/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4221 - accuracy: 0.8042
# Epoch 21: val_loss improved from 0.44241 to 0.44143, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 704s 67ms/step - loss: 0.4221 - accuracy: 0.8042 - val_loss: 0.4414 - val_accuracy: 0.7899 - lr: 1.1407e-05
# Epoch 22/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4211 - accuracy: 0.8044
# Epoch 22: val_loss improved from 0.44143 to 0.44058, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 750s 71ms/step - loss: 0.4211 - accuracy: 0.8044 - val_loss: 0.4406 - val_accuracy: 0.7906 - lr: 1.1126e-05
# Epoch 23/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4203 - accuracy: 0.8048
# Epoch 23: val_loss improved from 0.44058 to 0.44007, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 757s 72ms/step - loss: 0.4203 - accuracy: 0.8048 - val_loss: 0.4401 - val_accuracy: 0.7907 - lr: 1.0901e-05
# Epoch 24/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4195 - accuracy: 0.8060
# Epoch 24: val_loss improved from 0.44007 to 0.43943, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 772s 73ms/step - loss: 0.4195 - accuracy: 0.8060 - val_loss: 0.4394 - val_accuracy: 0.7920 - lr: 1.0721e-05
# Epoch 25/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4186 - accuracy: 0.8052
# Epoch 25: val_loss improved from 0.43943 to 0.43936, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 769s 73ms/step - loss: 0.4186 - accuracy: 0.8052 - val_loss: 0.4394 - val_accuracy: 0.7930 - lr: 1.0576e-05
# Epoch 26/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4180 - accuracy: 0.8060
# Epoch 26: val_loss improved from 0.43936 to 0.43842, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 809s 77ms/step - loss: 0.4180 - accuracy: 0.8060 - val_loss: 0.4384 - val_accuracy: 0.7929 - lr: 1.0461e-05
# Epoch 27/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4173 - accuracy: 0.8065
# Epoch 27: val_loss improved from 0.43842 to 0.43774, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 775s 73ms/step - loss: 0.4173 - accuracy: 0.8064 - val_loss: 0.4377 - val_accuracy: 0.7928 - lr: 1.0369e-05
# Epoch 28/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4166 - accuracy: 0.8065
# Epoch 28: val_loss improved from 0.43774 to 0.43723, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 765s 72ms/step - loss: 0.4166 - accuracy: 0.8065 - val_loss: 0.4372 - val_accuracy: 0.7930 - lr: 1.0295e-05
# Epoch 29/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4160 - accuracy: 0.8067
# Epoch 29: val_loss improved from 0.43723 to 0.43697, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 799s 76ms/step - loss: 0.4160 - accuracy: 0.8067 - val_loss: 0.4370 - val_accuracy: 0.7932 - lr: 1.0236e-05
# Epoch 30/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4153 - accuracy: 0.8078
# Epoch 30: val_loss improved from 0.43697 to 0.43694, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 782s 74ms/step - loss: 0.4153 - accuracy: 0.8078 - val_loss: 0.4369 - val_accuracy: 0.7950 - lr: 1.0189e-05
# Epoch 31/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4148 - accuracy: 0.8081
# Epoch 31: val_loss improved from 0.43694 to 0.43581, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 771s 73ms/step - loss: 0.4148 - accuracy: 0.8081 - val_loss: 0.4358 - val_accuracy: 0.7945 - lr: 1.0151e-05
# Epoch 32/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4142 - accuracy: 0.8078
# Epoch 32: val_loss improved from 0.43581 to 0.43537, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 765s 72ms/step - loss: 0.4141 - accuracy: 0.8078 - val_loss: 0.4354 - val_accuracy: 0.7941 - lr: 1.0121e-05
# Epoch 33/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4136 - accuracy: 0.8086
# Epoch 33: val_loss improved from 0.43537 to 0.43486, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 768s 73ms/step - loss: 0.4136 - accuracy: 0.8086 - val_loss: 0.4349 - val_accuracy: 0.7953 - lr: 1.0097e-05
# Epoch 34/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4130 - accuracy: 0.8087
# Epoch 34: val_loss improved from 0.43486 to 0.43460, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 766s 72ms/step - loss: 0.4130 - accuracy: 0.8087 - val_loss: 0.4346 - val_accuracy: 0.7959 - lr: 1.0077e-05
# Epoch 35/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4125 - accuracy: 0.8087
# Epoch 35: val_loss improved from 0.43460 to 0.43411, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 758s 72ms/step - loss: 0.4125 - accuracy: 0.8087 - val_loss: 0.4341 - val_accuracy: 0.7959 - lr: 1.0062e-05
# Epoch 36/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4120 - accuracy: 0.8097
# Epoch 36: val_loss improved from 0.43411 to 0.43380, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 782s 74ms/step - loss: 0.4120 - accuracy: 0.8097 - val_loss: 0.4338 - val_accuracy: 0.7962 - lr: 1.0050e-05
# Epoch 37/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4114 - accuracy: 0.8096
# Epoch 37: val_loss improved from 0.43380 to 0.43362, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 749s 71ms/step - loss: 0.4114 - accuracy: 0.8096 - val_loss: 0.4336 - val_accuracy: 0.7965 - lr: 1.0040e-05
# Epoch 38/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4109 - accuracy: 0.8099
# Epoch 38: val_loss improved from 0.43362 to 0.43297, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 777s 74ms/step - loss: 0.4109 - accuracy: 0.8099 - val_loss: 0.4330 - val_accuracy: 0.7967 - lr: 1.0032e-05
# Epoch 39/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4104 - accuracy: 0.8100
# Epoch 39: val_loss did not improve from 0.43297
# 10567/10567 [==============================] - 771s 73ms/step - loss: 0.4104 - accuracy: 0.8100 - val_loss: 0.4332 - val_accuracy: 0.7955 - lr: 1.0025e-05
# Epoch 40/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4100 - accuracy: 0.8102
# Epoch 40: val_loss improved from 0.43297 to 0.43245, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 796s 75ms/step - loss: 0.4100 - accuracy: 0.8102 - val_loss: 0.4325 - val_accuracy: 0.7969 - lr: 1.0020e-05
# Epoch 41/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4095 - accuracy: 0.8114
# Epoch 41: val_loss improved from 0.43245 to 0.43202, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 780s 74ms/step - loss: 0.4095 - accuracy: 0.8114 - val_loss: 0.4320 - val_accuracy: 0.7965 - lr: 1.0016e-05
# Epoch 42/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4091 - accuracy: 0.8108
# Epoch 42: val_loss improved from 0.43202 to 0.43168, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 768s 73ms/step - loss: 0.4091 - accuracy: 0.8108 - val_loss: 0.4317 - val_accuracy: 0.7974 - lr: 1.0013e-05
# Epoch 43/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4086 - accuracy: 0.8102
# Epoch 43: val_loss improved from 0.43168 to 0.43135, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 779s 74ms/step - loss: 0.4086 - accuracy: 0.8102 - val_loss: 0.4313 - val_accuracy: 0.7972 - lr: 1.0010e-05
# Epoch 44/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4081 - accuracy: 0.8125
# Epoch 44: val_loss improved from 0.43135 to 0.43107, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 764s 72ms/step - loss: 0.4081 - accuracy: 0.8125 - val_loss: 0.4311 - val_accuracy: 0.7977 - lr: 1.0008e-05
# Epoch 45/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4078 - accuracy: 0.8116
# Epoch 45: val_loss improved from 0.43107 to 0.43089, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 775s 73ms/step - loss: 0.4078 - accuracy: 0.8116 - val_loss: 0.4309 - val_accuracy: 0.7975 - lr: 1.0007e-05
# Epoch 46/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4074 - accuracy: 0.8118
# Epoch 46: val_loss did not improve from 0.43089
# 10567/10567 [==============================] - 766s 73ms/step - loss: 0.4074 - accuracy: 0.8118 - val_loss: 0.4312 - val_accuracy: 0.7991 - lr: 1.0005e-05
# Epoch 47/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4070 - accuracy: 0.8113
# Epoch 47: val_loss improved from 0.43089 to 0.43033, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 789s 75ms/step - loss: 0.4070 - accuracy: 0.8113 - val_loss: 0.4303 - val_accuracy: 0.7983 - lr: 1.0004e-05
# Epoch 48/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4065 - accuracy: 0.8117
# Epoch 48: val_loss improved from 0.43033 to 0.42994, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 779s 74ms/step - loss: 0.4065 - accuracy: 0.8117 - val_loss: 0.4299 - val_accuracy: 0.7981 - lr: 1.0003e-05
# Epoch 49/50
# 10567/10567 [==============================] - ETA: 0s - loss: 0.4062 - accuracy: 0.8123
# Epoch 49: val_loss improved from 0.42994 to 0.42973, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 758s 72ms/step - loss: 0.4062 - accuracy: 0.8123 - val_loss: 0.4297 - val_accuracy: 0.7989 - lr: 1.0003e-05
# Epoch 50/50
# 10566/10567 [============================>.] - ETA: 0s - loss: 0.4059 - accuracy: 0.8124
# Epoch 50: val_loss improved from 0.42973 to 0.42946, saving model to ModelWeights.h5
# 10567/10567 [==============================] - 748s 71ms/step - loss: 0.4059 - accuracy: 0.8124 - val_loss: 0.4295 - val_accuracy: 0.7986 - lr: 1.0002e-05
#
# Restoring best Weights for MobileNetV2

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure()
    train_values = history.history[item][0:index]
    plt.plot(train_values)
    test_values = history.history['val_' + item][0:index]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)


def get_best_epoch(test_loss, history):
    for key, item in enumerate(history.history.items()):
        (name, arr) = item
        if name == 'val_loss':
            for i in range(len(arr)):
                if round(test_loss, 2) == round(arr[i], 2):
                    return i

def model_summary(model, history):
    print('---'*30)
    test_loss, test_accuracy = model.evaluate(X_test_nn, y_test, verbose=0)

    if history:
        index = get_best_epoch(test_loss, history)
        print('Best Epochs: ', index)

        train_accuracy = history.history['accuracy'][index]
        train_loss = history.history['loss'][index]

        print('Accuracy on train:',train_accuracy,'\tLoss on train:',train_loss)
        print('Accuracy on test:',test_accuracy,'\tLoss on test:',test_loss)
        print_graph('loss', index, history)
        print_graph('accuracy', index, history)
        print('---'*30)

# %%
model_summary(model, history)
# Out:
# ------------------------------------------------------------------------------------------
# Best Epochs:  32
# Accuracy on train: 0.8085504174232483 	Loss on train: 0.4135741591453552
# Accuracy on test: 0.7985647320747375 	Loss on test: 0.4294644594192505
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## **Evaluation on test set**

# %%
# evaluate the network
print("Evaluating network...")
predictions = model.predict(X_test_nn)
preds = predictions > 0.5
# Out:
# Evaluating network...
# 567/567 [==============================] - 111s 190ms/step

# %%
import seaborn as sns
from sklearn import metrics 
import sklearn 
#from sklearn.metrics import roc_curve, roc_auc_score, plot_roc_curve, accuracy_score, classification_report, confusion_matrix
corr_pred = metrics.confusion_matrix(y_test, preds)

n_correct = int((corr_pred[0][0] + corr_pred[1][1]))
print('> Correct Predictions:', n_correct)
n_wrongs = int((corr_pred[0][1] + (corr_pred[1][0])))
print('> Wrong Predictions:', n_wrongs)

sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Blues")
plt.show()

print(metrics.classification_report(y_test, preds,
                           target_names=["NonViolence", "Violence"]))
# Out:
# > Correct Predictions: 14466
# > Wrong Predictions: 3649
#               precision    recall  f1-score   support
#
#  NonViolence       0.81      0.79      0.80      9120
#     Violence       0.79      0.81      0.80      8995
#
#     accuracy                           0.80     18115
#    macro avg       0.80      0.80      0.80     18115
# weighted avg       0.80      0.80      0.80     18115

# %%
args_model = "modelnew23.h5"
model.save(args_model)
